# %%
import cv2
import os

# %%
# Overlaying_of_Prediction_Image

path = input('Input your image folder path: ')
path = path.replace('\\', '/') + '/'
img_file = os.listdir(path) #讀取整個資料夾該層的內容
img_amount = len(img_file) #用以計算資料夾中的圖片張數

for i in range(0, img_amount, 2): # 設定步長為2的原因:加疊兩張照片為一張
    if os.path.isfile(path + img_file[i][:-10] + '_overlay.png'):
        print('{}_overlay.png has already existed.'.format(img_file[i][:-10]))
        break
            
    elif i >= 100:
        buttom = path + img_file[i][:-10] + '_image.png'   # 重新命名圖片, 以方便迭代處理
        top = path + img_file[i][:-10] + '_prediction.png' # 重新命名圖片, 以方便迭代處理
        buttom = cv2.imread(buttom)
        top = cv2.imread(top)
        overlay_img = cv2.addWeighted(buttom, 0.7, top, 0.7, 0)
        cv2.imwrite(path + img_file[i][:-10] + '_overlay.png', overlay_img)
        print('Downloading {}_overlay.png: finished!'.format(img_file[i][:-10]))
        
    elif i>=10:
        buttom = path + img_file[i][:-10] + '_image.png'
        top = path + img_file[i][:-10] + '_prediction.png'
        buttom = cv2.imread(buttom)
        top = cv2.imread(top)
        overlay_img = cv2.addWeighted(buttom, 0.7, top, 0.7, 0)
        cv2.imwrite(path + img_file[i][:-10] + '_overlay.png', overlay_img)
        print('Downloading {}_overlay.png: finished!'.format(img_file[i][:-10]))
    
    else:
        buttom = path + img_file[i][:-10] + '_image.png'
        top = path + img_file[i][:-10] + '_prediction.png'
        buttom = cv2.imread(buttom)
        top = cv2.imread(top)
        overlay_img = cv2.addWeighted(buttom, 0.7, top, 0.7, 0)
        cv2.imwrite(path + img_file[i][:-10] + '_overlay.png', overlay_img)
        print('Downloading {}_overlay.png: finished!'.format(img_file[i][:-10]))
    
print('All finished!')
# Out:
# Downloading 000000_overlay.png finished!
# Downloading 000001_overlay.png finished!
# Downloading 000002_overlay.png finished!
# Downloading 000003_overlay.png finished!
# Downloading 000004_overlay.png finished!
# Downloading 000005_overlay.png finished!
# Downloading 000006_overlay.png finished!
# Downloading 000007_overlay.png finished!
# Downloading 000008_overlay.png finished!
# Downloading 000009_overlay.png finished!
# Downloading 000010_overlay.png finished!
# Downloading 000011_overlay.png finished!
# Downloading 000012_overlay.png finished!
# Downloading 000013_overlay.png finished!
# Downloading 000014_overlay.png finished!
# Downloading 000015_overlay.png finished!
# Downloading 000016_overlay.png finished!
# Downloading 000017_overlay.png finished!
# Downloading 000018_overlay.png finished!
# Downloading 000019_overlay.png finished!
# Downloading 000020_overlay.png finished!
# Downloading 000021_overlay.png finished!
# Downloading 000022_overlay.png finished!
# Downloading 000023_overlay.png finished!
# Downloading 000024_overlay.png finished!
# Downloading 000025_overlay.png finished!
# Downloading 000026_overlay.png finished!
# Downloading 000027_overlay.png finished!
# Downloading 000028_overlay.png finished!
# Downloading 000029_overlay.png finished!
# Downloading 000030_overlay.png finished!
# Downloading 000031_overlay.png finished!
# Downloading 000032_overlay.png finished!
# Downloading 000033_overlay.png finished!
# Downloading 000034_overlay.png finished!
# Downloading 000035_overlay.png finished!
# Downloading 000036_overlay.png finished!
# Downloading 000037_overlay.png finished!
# Downloading 000038_overlay.png finished!
# Downloading 000039_overlay.png finished!
# Downloading 000040_overlay.png finished!
# Downloading 000041_overlay.png finished!
# Downloading 000042_overlay.png finished!
# Downloading 000043_overlay.png finished!
# Downloading 000044_overlay.png finished!
# Downloading 000045_overlay.png finished!
# Downloading 000046_overlay.png finished!
# Downloading 000047_overlay.png finished!
# Downloading 000048_overlay.png finished!
# Downloading 000049_overlay.png finished!
# Downloading 000050_overlay.png finished!
# Downloading 000051_overlay.png finished!
# Downloading 000052_overlay.png finished!
# Downloading 000053_overlay.png finished!
# Downloading 000054_overlay.png finished!
# Downloading 000055_overlay.png finished!
# Downloading 000056_overlay.png finished!
# Downloading 000057_overlay.png finished!
# Downloading 000058_overlay.png finished!
# Downloading 000059_overlay.png finished!
# Downloading 000060_overlay.png finished!
# Downloading 000061_overlay.png finished!
# Downloading 000062_overlay.png finished!
# Downloading 000063_overlay.png finished!
# Downloading 000064_overlay.png finished!
# Downloading 000065_overlay.png finished!
# Downloading 000066_overlay.png finished!
# Downloading 000067_overlay.png finished!
# Downloading 000068_overlay.png finished!
# Downloading 000069_overlay.png finished!
# Downloading 000070_overlay.png finished!
# Downloading 000071_overlay.png finished!
# Downloading 000072_overlay.png finished!
# Downloading 000073_overlay.png finished!
# Downloading 000074_overlay.png finished!
# Downloading 000075_overlay.png finished!
# All finished!
